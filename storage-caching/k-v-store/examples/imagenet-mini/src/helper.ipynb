# %%
""" upload one directory from the current working directory to aws """
from pathlib import Path
import os
import glob
import boto3


def upload_dir(localDir, awsInitDir, bucketName, tag, prefix='/'):
    """
    from current working directory, upload a 'localDir' with all its subcontents (files and subdirectories...)
    to a aws bucket
    Parameters
    ----------
    localDir :   localDirectory to be uploaded, with respect to current working directory
    awsInitDir : prefix 'directory' in aws
    bucketName : bucket in aws
    tag :        tag to select files, like *png
                 NOTE: if you use tag it must be given like --tag '*txt', in some quotation marks... for argparse
    prefix :     to remove initial '/' from file names

    Returns
    -------
    None
    """
    s3 = boto3.resource('s3')
    cwd = str(Path.cwd())
    p = Path(os.path.join(Path.cwd(), localDir))
    mydirs = list(p.glob('**'))
    for mydir in mydirs:
        fileNames = glob.glob(os.path.join(mydir, tag))
        fileNames = [f for f in fileNames if not Path(f).is_dir()]
        rows = len(fileNames)
        for i, fileName in enumerate(fileNames):
            fileName = str(fileName).replace(cwd, '')
            if fileName.startswith(prefix):  # only modify the text if it starts with the prefix
                fileName = fileName.replace(prefix, "", 1) # remove one instance of prefix
            print(f"fileName {fileName}")

            awsPath = os.path.join(awsInitDir, str(fileName))
            s3.meta.client.upload_file(fileName, bucketName, awsPath)

# %%
upload_dir('imagenet-mini', '', 'zhuangwei-bucket', '*.JPEG')

# %%
bucket_name = 'zhuangwei-bucket'
client = boto3.client('s3')
s3 = boto3.resource('s3')
bucket_obj = s3.Bucket(bucket_name)

response = client.list_objects(Bucket=bucket_name, Prefix='imagenet-mini/train/n01440764')['Contents']

# %%
response
# Out:
# [{'Key': 'imagenet-mini/train/n01440764/n01440764_10043.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 45, tzinfo=tzutc()),
#   'ETag': '"1e2d14641e2091e222e80fe4a309a3f5"',
#   'Size': 68487,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_10470.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 49, tzinfo=tzutc()),
#   'ETag': '"1de77225c793ce27769db6338135d3c4"',
#   'Size': 127866,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_10744.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 50, tzinfo=tzutc()),
#   'ETag': '"ae78f8d3de8dd50e0653d099ff218c1b"',
#   'Size': 106594,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_10845.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 48, tzinfo=tzutc()),
#   'ETag': '"75ac970ea4ff2e8f9f6e6fc64a1ac393"',
#   'Size': 142752,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_11170.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 50, tzinfo=tzutc()),
#   'ETag': '"885f6bb2a2eec4bfb2fc4a011011eb87"',
#   'Size': 232127,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_12021.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 46, tzinfo=tzutc()),
#   'ETag': '"a002313a5aaf048c1ab45f7d838ec6ec"',
#   'Size': 178351,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_12063.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 46, tzinfo=tzutc()),
#   'ETag': '"b4cb9f395aba5c656fe0f0922525cee7"',
#   'Size': 42356,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_12090.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 49, tzinfo=tzutc()),
#   'ETag': '"08714fced592ee5a4c086ad784c0f7d7"',
#   'Size': 190692,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_12329.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 48, tzinfo=tzutc()),
#   'ETag': '"0d50c415b2752ec1384a81891844b3c0"',
#   'Size': 156446,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_12435.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 44, tzinfo=tzutc()),
#   'ETag': '"fa1e0ae68a7d326dadc503acc71ee1c8"',
#   'Size': 105283,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_12534.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 48, tzinfo=tzutc()),
#   'ETag': '"99775d24ffd7195ca3c9280a857d58ed"',
#   'Size': 60032,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_13545.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 47, tzinfo=tzutc()),
#   'ETag': '"4eb518f8a79016950c95ec51a04d8b18"',
#   'Size': 269345,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_14411.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 44, tzinfo=tzutc()),
#   'ETag': '"02ac1d4d2cb2f209004bd97a85f8357b"',
#   'Size': 61061,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_14448.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 46, tzinfo=tzutc()),
#   'ETag': '"b49f44912f8ad2d07c5fbd382cb60797"',
#   'Size': 51007,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_14731.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 51, tzinfo=tzutc()),
#   'ETag': '"757af4ace5b1ab36ec8b0e0354f38924"',
#   'Size': 136068,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_15071.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 49, tzinfo=tzutc()),
#   'ETag': '"558a0e1d40c8b521c4158e33064e5647"',
#   'Size': 32361,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_15560.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 51, tzinfo=tzutc()),
#   'ETag': '"e86e9c944616e5606092fb128dc3fe39"',
#   'Size': 104997,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_1775.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 44, tzinfo=tzutc()),
#   'ETag': '"85e3f0199338f3a74c4716869874e5b4"',
#   'Size': 170463,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_31518.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 45, tzinfo=tzutc()),
#   'ETag': '"0a7b3e12dd7de6a7df1ba36e51f11547"',
#   'Size': 94327,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_3236.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 50, tzinfo=tzutc()),
#   'ETag': '"ca25c4af0a0d2fdaa9aa90c11666d5fd"',
#   'Size': 154031,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_3603.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 48, tzinfo=tzutc()),
#   'ETag': '"0400bbfbf3fa05ce86ccc0ca188eac1e"',
#   'Size': 180163,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_4397.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 51, tzinfo=tzutc()),
#   'ETag': '"970ff95694c24cdbd1d38873f81a1e6f"',
#   'Size': 58105,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_4852.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 50, tzinfo=tzutc()),
#   'ETag': '"b2dbf4b9ea83e54933e849d3bada5790"',
#   'Size': 126879,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_4965.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 47, tzinfo=tzutc()),
#   'ETag': '"8695740f30aa3377eb9d3f91860ae2ce"',
#   'Size': 62519,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_4979.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 46, tzinfo=tzutc()),
#   'ETag': '"99df13089e98ddf3ac4fb94520cc1b1e"',
#   'Size': 147572,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_5087.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 44, tzinfo=tzutc()),
#   'ETag': '"3e9514377e13ac28bc5f861c1aec6297"',
#   'Size': 29826,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_5376.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 47, tzinfo=tzutc()),
#   'ETag': '"6daed76cfbfde25caed64e6263e744c5"',
#   'Size': 69293,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_5638.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 47, tzinfo=tzutc()),
#   'ETag': '"874b8468e716172c8ad9f22f9dc1e122"',
#   'Size': 77769,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_5785.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 45, tzinfo=tzutc()),
#   'ETag': '"371437a62f69a4230e34bc22260a3cb3"',
#   'Size': 6750,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_6206.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 46, tzinfo=tzutc()),
#   'ETag': '"d4bacfdf96372759a09eed1867879db2"',
#   'Size': 24686,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_6425.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 49, tzinfo=tzutc()),
#   'ETag': '"ca43bb83f6bd0cd64163644bf07749fb"',
#   'Size': 171733,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_8710.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 50, tzinfo=tzutc()),
#   'ETag': '"1fe072b02390762e6e94226a6fbf0445"',
#   'Size': 85252,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_9157.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 47, tzinfo=tzutc()),
#   'ETag': '"16a538cc9801502dabeb2262a585d4c9"',
#   'Size': 13710,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}},
#  {'Key': 'imagenet-mini/train/n01440764/n01440764_9779.JPEG',
#   'LastModified': datetime.datetime(2022, 6, 27, 21, 32, 45, tzinfo=tzutc()),
#   'ETag': '"e27ff842cf23c01dc8611d01bf83a329"',
#   'Size': 144346,
#   'StorageClass': 'STANDARD',
#   'Owner': {'DisplayName': 'usrdaws4alnair',
#    'ID': 'eecea9d3a80c45e553445e77d78c203925fe9b169a35da7089fd4e9332fb9b74'}}]

# %%
data = []
for k in list(map(lambda x: x['Key'], response)):
    data.append(client.get_object(Bucket=bucket_name, Key=k)['Body'].read())

# %%
bucket_obj.download_file(Key='imagenet-mini/train/n01440764', Filename='/tmp/n01440764')
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /home/zhuangwei/alnair/storage-caching/k-v-store/examples/imagenet-mini/helper.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B32/home/zhuangwei/alnair/storage-caching/k-v-store/examples/imagenet-mini/helper.ipynb#ch0000009vscode-remote?line=0'>1</a> bucket_obj.download_file(Key='imagenet-mini/train/n01440764', Filename='/tmp/n01440764')
#
# File ~/boto3/boto3/s3/inject.py:277, in bucket_download_file(self, Key, Filename, ExtraArgs, Callback, Config)
#     243 def bucket_download_file(
#     244     self, Key, Filename, ExtraArgs=None, Callback=None, Config=None
#     245 ):
#     246     """Download an S3 object to a file.
#     247
#     248     Usage::
#    (...)
#     275         transfer.
#     276     """
# --> 277     return self.meta.client.download_file(
#     278         Bucket=self.name,
#     279         Key=Key,
#     280         Filename=Filename,
#     281         ExtraArgs=ExtraArgs,
#     282         Callback=Callback,
#     283         Config=Config,
#     284     )
#
# File ~/boto3/boto3/s3/inject.py:190, in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     155 """Download an S3 object to a file.
#     156
#     157 Usage::
#    (...)
#     187     transfer.
#     188 """
#     189 with S3Transfer(self, Config) as transfer:
# --> 190     return transfer.download_file(
#     191         bucket=Bucket,
#     192         key=Key,
#     193         filename=Filename,
#     194         extra_args=ExtraArgs,
#     195         callback=Callback,
#     196     )
#
# File ~/boto3/boto3/s3/transfer.py:320, in S3Transfer.download_file(self, bucket, key, filename, extra_args, callback)
#     316 future = self._manager.download(
#     317     bucket, key, filename, extra_args, subscribers
#     318 )
#     319 try:
# --> 320     future.result()
#     321 # This is for backwards compatibility where when retries are
#     322 # exceeded we need to throw the same error from boto3 instead of
#     323 # s3transfer's built in RetriesExceededError as current users are
#     324 # catching the boto3 one instead of the s3transfer exception to do
#     325 # their own retries.
#     326 except S3TransferRetriesExceededError as e:
#
# File ~/boto3/src/s3transfer/s3transfer/futures.py:103, in TransferFuture.result(self)
#      98 def result(self):
#      99     try:
#     100         # Usually the result() method blocks until the transfer is done,
#     101         # however if a KeyboardInterrupt is raised we want want to exit
#     102         # out of this and propagate the exception.
# --> 103         return self._coordinator.result()
#     104     except KeyboardInterrupt as e:
#     105         self.cancel()
#
# File ~/boto3/src/s3transfer/s3transfer/futures.py:266, in TransferCoordinator.result(self)
#     263 # Once done waiting, raise an exception if present or return the
#     264 # final result.
#     265 if self._exception:
# --> 266     raise self._exception
#     267 return self._result
#
# File ~/boto3/src/s3transfer/s3transfer/tasks.py:269, in SubmissionTask._main(self, transfer_future, **kwargs)
#     265     self._transfer_coordinator.set_status_to_running()
#     267     # Call the submit method to start submitting tasks to execute the
#     268     # transfer.
# --> 269     self._submit(transfer_future=transfer_future, **kwargs)
#     270 except BaseException as e:
#     271     # If there was an exception raised during the submission of task
#     272     # there is a chance that the final task that signals if a transfer
#    (...)
#     281
#     282     # Set the exception, that caused the process to fail.
#     283     self._log_and_set_exception(e)
#
# File ~/boto3/src/s3transfer/s3transfer/download.py:354, in DownloadSubmissionTask._submit(self, client, config, osutil, request_executor, io_executor, transfer_future, bandwidth_limiter)
#     325 """
#     326 :param client: The client associated with the transfer manager
#     327
#    (...)
#     349     downloading streams
#     350 """
#     351 if transfer_future.meta.size is None:
#     352     # If a size was not provided figure out the size for the
#     353     # user.
# --> 354     response = client.head_object(
#     355         Bucket=transfer_future.meta.call_args.bucket,
#     356         Key=transfer_future.meta.call_args.key,
#     357         **transfer_future.meta.call_args.extra_args,
#     358     )
#     359     transfer_future.meta.provide_transfer_size(
#     360         response['ContentLength']
#     361     )
#     363 download_output_manager = self._get_download_output_manager_cls(
#     364     transfer_future, osutil
#     365 )(osutil, self._transfer_coordinator, io_executor)
#
# File ~/boto3/src/botocore/botocore/client.py:508, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     504     raise TypeError(
#     505         f"{py_operation_name}() only accepts keyword arguments."
#     506     )
#     507 # The "self" in this scope is referring to the BaseClient.
# --> 508 return self._make_api_call(operation_name, kwargs)
#
# File ~/boto3/src/botocore/botocore/client.py:911, in BaseClient._make_api_call(self, operation_name, api_params)
#     909     error_code = parsed_response.get("Error", {}).get("Code")
#     910     error_class = self.exceptions.from_code(error_code)
# --> 911     raise error_class(parsed_response, operation_name)
#     912 else:
#     913     return parsed_response
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found

# %%
paginator = client.get_paginator('list_objects_v2')
page_iterator = paginator.paginate(Bucket=bucket_name)

dataset_info = {}
for bucket in page_iterator:
    for obj in bucket['Contents']:
        if obj['Key'] not in keys: continue
        metadata = client.head_object(Bucket=bucket_name, Key=obj['Key'])
        dataset_info.update({obj['Key']: metadata})

# %%
len(dataset_info)
# Out:
# 1000

# %%
import sys

sys.getsizeof(data)
# Out:
# 336
